# %%
# %load_ext rpy2.ipython
# %load_ext rmagic

import numpy as np 
import pandas as pd

# %%
# %%R
#
# library(MARSS)

# %%
x = np.array([1,2,4,6,5,8])
y = np.array([0,1,3,2,5,7])

meas = np.array(pd.DataFrame([[1,0], [7,1], [0,1],[1,9],[np.nan,np.nan]])).transpose()
# meas = pd.DataFrame([[1,0], [7,1], [0,1],[2,0]])
# measMat = np.array(meas)

# %%
# %%R -i meas
#
# # class(meas)
#
# Z="unconstrained"
# B="unconstrained"
# # x0=matrix(c("pi1"),1,1)
# x0=matrix(c("pi1","pi2"),2,1)
#
# Z=matrix(list("z1","z2"),2,1)
#
# model.gen=list(Z=Z,B=B,A="zero",x0="zero",U="zero")
# # model.gen=list(Z=Z,B=B,x0=x0,A="zero")
# kemfit = MARSS(meas, model=model.gen)
#
# # print(kemfit, what="model")
# # print(kemfit, what="start")
# print(kemfit, what="states")
# # print(kemfit, what="ytT")
# # print(kemfit, what="states.se")
# Out:
# MARSS: NaNs in data are being replaced with NAs.  There might be a problem is NaNs shouldn't be in the data.
# NA is the normal missing value designation.
# Success! abstol and log-log tests passed at 195 iterations.
# Alert: conv.test.slope.tol is 0.5.
# Test with smaller values (<0.1) to ensure convergence.
#
# MARSS fit is
# Estimation method: kem
# Convergence test: conv.test.slope.tol = 0.5, abstol = 0.001
# Estimation converged in 195 iterations.
# Log-likelihood: -20.70868
# AIC: 51.41737   AICc: 81.41737
#
#        Estimate
# Z.z1      0.260
# Z.z2      1.053
# R.diag    7.746
# B.B       2.286
# Q.Q       0.281
#
# Standard errors have not been calculated.
# Use MARSSparamCIs to compute CIs and bias estimates.
#
# Smoothed state estimates
#         [,1]     [,2]     [,3]     [,4]     [,5]
# X1 0.4546464 1.242675 2.907588 6.714224 15.35044

# %%
# %%R -i meas
#
# # class(meas)
#
# Z="unconstrained"
# B="unconstrained"
# # x0=matrix(c("pi1"),1,1)
# x0=matrix(c("pi1","pi2"),2,1)
#
# # Z=matrix(list("z1","z2"),2,1)
#
# model.gen=list(Z=Z,B=B,A="zero",x0="zero",U="zero")
# # model.gen=list(Z=Z,B=B,x0=x0,A="zero")
# kemfit = MARSS(meas, model=model.gen)
#
# # print(kemfit, what="model")
# # print(kemfit, what="start")
# print(kemfit, what="states")
# # print(kemfit, what="ytT")
# # print(kemfit, what="states.se")
# Out:
# MARSS: NaNs in data are being replaced with NAs.  There might be a problem is NaNs shouldn't be in the data.
# NA is the normal missing value designation.
# Success! abstol and log-log tests passed at 117 iterations.
# Alert: conv.test.slope.tol is 0.5.
# Test with smaller values (<0.1) to ensure convergence.
#
# MARSS fit is
# Estimation method: kem
# Convergence test: conv.test.slope.tol = 0.5, abstol = 0.001
# Estimation converged in 117 iterations.
# Log-likelihood: -20.76548
# AIC: 63.53096   AICc: NA, number of data points less than K+1
#
#           Estimate
# Z.(1,1)      0.247
# Z.(2,1)      0.930
# Z.(1,2)      0.247
# Z.(2,2)      0.930
# R.diag       7.880
# B.(1,1)      1.566
# B.(2,1)      0.566
# B.(1,2)      0.566
# B.(2,2)      1.566
# Q.(X1,X1)    0.256
# Q.(X2,X2)    0.256
#
# Standard errors have not been calculated.
# Use MARSSparamCIs to compute CIs and bias estimates.
#
# Smoothed state estimates
#         [,1]      [,2]     [,3]     [,4]     [,5]
# ...

# %%
# %%R
#
# ?print.MARSS
# Out:
# R Help on ‘print.MARSS’print.marssMLE              package:MARSS              R Documentation
#
# s
#
# n:
#
#      The MARSS fitting function, ‘MARSS’, outputs ‘marssMLE’ objects.
#      ‘print(marssMLE)’, where ‘marssMLE’ is a ‘marssMLE’ object, will
#      print out information on the fit.  However, ‘print’ can be used to
#      print a variety of information (residuals, smoothed states,
#      imputed missing values, etc) from a ‘marssMLE’ object using the
#      ‘what’ argument in the print call.
#
# e:
#
#      ## S3 method for class 'marssMLE'
#      print(x, digits = max(3, getOption("digits")-4), ..., what="fit", form=NULL, silent=FALSE)
#
# s:
#
#        x: A marssMLE object.
#
#   digits: Number of digits for printing.
#
#      ...: Other arguments for print.
#
#     what: What to print.  Default is "fit".  If you input what as a
#           vector, print returns a list. See examples.
#
#             • "model" The model parameters with names for the estimted
# ...
